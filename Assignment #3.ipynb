# %%
import random
import textwrap

# %%
love_letters = open("./love_letters.txt").readlines()

# %%
love_letters
# Out:
# ['I need not tell you that since we left, all my thoughts have been with you at Windsor, and that your image fills my whole soul. \n',
#  'Even in my dreams I never imagined that I should find so much love on earth. \n',
#  'How that moment shines for me still when I was close to you, with your hand in mine. \n',
#  'Those days flew by so quickly, but our separation will fly equally so. \n',
#  'Ernest [my brother] wishes me to say a thousand nice things to you. \n',
#  '\n',
#  '…should I draw you the picture of my heart it would be what I hope you would still love though it contained nothing new. \n',
#  'The early possession you obtained there, and the absolute power you have obtained over it, leaves not the smallest space unoccupied.\n',
#  'I look back to the early days of our acquaintance and friendship as to the days of love and innocence, and, with an indescribable pleasure, \n',
# ...

# %%
rap_lyrics = open("./rap_lyrics.txt").readlines()

# %%
rap_lyrics
# Out:
# ['It’s kinda hard to imagine, like Kanye West coming back from his fatal accident to beatmaking and rapping.\n',
#  '\n',
#  'She got a light skin friend, look like Michael Jackson. Got a dark skin friend, look like Michael Jackson.\n',
#  '\n',
#  'If you don’t want to, I can live with that, but you gotta put back the double-knit reversible slacks.\n',
#  '\n',
#  'Girl you’re hot and cold. That makes you warm..\n',
#  '\n',
#  'Dinner: you ate it. There is none left. It was salty with butter, and it was def. You proceeded to eat it cos you was in the mood. But homes you did not read it was a can of dog food.\n',
#  '\n',
#  'Have you ever seen crocodile seats in the truck? Turn around, sit down, let ’em bite yo butt.\n',
#  '\n',
#  'Thirty-eight revolve like the sun round the Earth.\n',
#  '\n',
#  'Watch out for the medallion. My diamonds are reckless. It feels like a midget is hanging from my necklace.\n',
#  '\n',
# ...

# %%
sal_adjs = [
    "Beloved",
    "Darling",
    "Dear",
    "Dearest",
    "Fanciful",
    "Honey"]

# %%
sal_nouns = [
    "Fool",
    "God",
    "Bubblegum Goon",
    "Dime",
    "Love",
    "Moppet",
    "Sweetheart"]

# %%
advs = [
    'badly',
    'loudly',
    'anxiously',
    'beautifully',
    'burningly',
    'covetously',
    'curiously',
    'eagerly',
    'fervently',
    'fondly',
    'impatiently',
    'keenly',
    'lovingly',
    'passionately',
    'seductively',
    'tenderly',
    'wistfully']

# %%
with open (love_letters) as file:
    words = file.read().split()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-23-a233a319c299> in <module>
# ----> 1 with open (love_letters) as file:
#       2     words = file.read().split()
#
# ...

# %%
# open the files which you want to append.
first_file = open("love_letters.txt")
second_file = open("rap_lyrics.txt")
 
# read lines
first_lines = first_file.readlines()
second_lines = second_file.readlines()

# %%
print (first_lines)
# Out:
# ['I need not tell you that since we left, all my thoughts have been with you at Windsor, and that your image fills my whole soul. \n', 'Even in my dreams I never imagined that I should find so much love on earth. \n', 'How that moment shines for me still when I was close to you, with your hand in mine. \n', 'Those days flew by so quickly, but our separation will fly equally so. \n', 'Ernest [my brother] wishes me to say a thousand nice things to you. \n', '\n', '…should I draw you the picture of my heart it would be what I hope you would still love though it contained nothing new. \n', 'The early possession you obtained there, and the absolute power you have obtained over it, leaves not the smallest space unoccupied.\n', 'I look back to the early days of our acquaintance and friendship as to the days of love and innocence, and, with an indescribable pleasure, \n', 'I have seen near a score of years roll over our heads with an affection heightened and improved by time, nor have the dr
# ...

# %%
print (second_lines)
# Out:
# ['It’s kinda hard to imagine, like Kanye West coming back from his fatal accident to beatmaking and rapping.\n', '\n', 'She got a light skin friend, look like Michael Jackson. Got a dark skin friend, look like Michael Jackson.\n', '\n', 'If you don’t want to, I can live with that, but you gotta put back the double-knit reversible slacks.\n', '\n', 'Girl you’re hot and cold. That makes you warm..\n', '\n', 'Dinner: you ate it. There is none left. It was salty with butter, and it was def. You proceeded to eat it cos you was in the mood. But homes you did not read it was a can of dog food.\n', '\n', 'Have you ever seen crocodile seats in the truck? Turn around, sit down, let ’em bite yo butt.\n', '\n', 'Thirty-eight revolve like the sun round the Earth.\n', '\n', 'Watch out for the medallion. My diamonds are reckless. It feels like a midget is hanging from my necklace.\n', '\n', 'Chuba chuba chuba chuba chuba chuba chubby. I don’t have any lines to go right here, so chuby Teletubby.\n',
# ...

# %%
# remove new line characters
first_lines = [line.strip() for line in first_lines]
second_lines = [line.strip() for line in second_lines] 
 
# empty dictionary to store the unique lines.
final_lines = {}
 
# loop through each lines, if the line is not present in the 
# keys of the dictionary, create an entry in dictionary 
# assigning any value (0).
for line in first_lines:
    if line not in final_lines.keys():
        final_lines[line] = 0
 
for line in second_lines:
    if line not in final_lines.keys():
        final_lines[line] = 0
 
# join the lines with "\n'
lines = "\n".join(list(final_lines.keys()))
 
# write the output to a text file
file = open("output.txt", "w")
file.write(lines+"\n")
 
# close the text file.
file.close()

# %%
import textwrap

# %%
newletter = open ("./output.txt")

words = newletter.split()
random.shuffle(words)

print(textwrap.fill(" ".join(words), 60))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-01526d84e363> in <module>
#       1 newletter = open ("./output.txt")
#       2
# ----> 3 words = newletter.split()
#       4 random.shuffle(words)
#       5
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'split'

# %%
for line in love_letters:
    print(line.rstrip())
    for line in rap_lyrics:
        print(line.rstrip())
# Out:
# I need not tell you that since we left, all my thoughts have been with you at Windsor, and that your image fills my whole soul.
# It’s kinda hard to imagine, like Kanye West coming back from his fatal accident to beatmaking and rapping.
#
# She got a light skin friend, look like Michael Jackson. Got a dark skin friend, look like Michael Jackson.
#
# If you don’t want to, I can live with that, but you gotta put back the double-knit reversible slacks.
#
# Girl you’re hot and cold. That makes you warm..
#
# Dinner: you ate it. There is none left. It was salty with butter, and it was def. You proceeded to eat it cos you was in the mood. But homes you did not read it was a can of dog food.
#
# Have you ever seen crocodile seats in the truck? Turn around, sit down, let ’em bite yo butt.
#
# Thirty-eight revolve like the sun round the Earth.
#
# Watch out for the medallion. My diamonds are reckless. It feels like a midget is hanging from my necklace.
#
# ...

# %%
for x in range (0,9):
    for line in love_letters:
        print(line.rstrip())
    for line in rap_lyrics:
        print(line.rstrip())
# Out:
# I need not tell you that since we left, all my thoughts have been with you at Windsor, and that your image fills my whole soul.
# Even in my dreams I never imagined that I should find so much love on earth.
# How that moment shines for me still when I was close to you, with your hand in mine.
# Those days flew by so quickly, but our separation will fly equally so.
# Ernest [my brother] wishes me to say a thousand nice things to you.
#
# …should I draw you the picture of my heart it would be what I hope you would still love though it contained nothing new.
# The early possession you obtained there, and the absolute power you have obtained over it, leaves not the smallest space unoccupied.
# I look back to the early days of our acquaintance and friendship as to the days of love and innocence, and, with an indescribable pleasure,
# ...
