# %%
longtext = open("the_bell_jar.txt").read()

# %%
longwords = longtext.split()

# %%
seed = 'abottomlesspitofselfloathing'

# %%
shorttext = open("figtree.txt").read()

# %%
shortwords = shorttext.split()

# %%
longwords
# Out:
# ['It',
#  'was',
#  'a',
#  'queer,',
#  'sultry',
#  'summer,',
#  'the',
#  'summer',
#  'they',
#  'electrocuted',
#  'the',
#  'Rosenbergs,',
#  'and',
#  'I',
#  "didn't",
#  'know',
#  'what',
#  'I',
#  'was',
#  'doing',
#  'in',
#  'New',
#  'York.',
#  "I'm",
#  'stupid',
#  'about',
#  'executions.',
#  'The',
#  'idea',
#  'of',
#  'being',
#  'electrocuted',
#  'makes',
#  'me',
#  'sick,',
#  'and',
#  "that's",
#  'all',
#  'there',
#  'was',
#  'to',
#  'read',
#  'about',
#  'in',
#  'the',
#  'papers—goggle-eyed',
#  'headlines',
#  'staring',
#  'up',
#  'at',
#  'me',
#  'on',
#  'every',
#  'street',
#  'corner',
#  'and',
#  'at',
#  'the',
#  'fusty,',
#  'peanut-smelling',
#  'mouth',
#  'of',
#  'every',
#  'subway.',
#  'It',
#  'had',
#  'nothing',
#  'to',
#  'do',
#  'with',
#  'me,',
#  'but',
#  'I',
#  "couldn't",
#  'help',
#  'wondering',
#  'what',
#  'it',
#  'would',
#  'be',
#  'like,',
#  'being',
#  'burned',
#  'alive',
#  'all',
#  'along',
# ...

# %%
shortwords
# Out:
# ['I',
#  'saw',
#  'my',
#  'life',
#  'branching',
#  'out',
#  'before',
#  'me',
#  'like',
#  'the',
#  'green',
#  'fig',
#  'tree',
#  'in',
#  'the',
#  'story.',
#  'From',
#  'the',
#  'tip',
#  'of',
#  'every',
#  'branch,',
#  'like',
#  'a',
#  'fat',
#  'purple',
#  'fig,',
#  'a',
#  'wonderful',
#  'future',
#  'beckoned',
#  'and',
#  'winked.',
#  'One',
#  'fig',
#  'was',
#  'a',
#  'husband',
#  'and',
#  'a',
#  'happy',
#  'home',
#  'and',
#  'children,',
#  'and',
#  'another',
#  'fig',
#  'was',
#  'a',
#  'famous',
#  'poet',
#  'and',
#  'another',
#  'fig',
#  'was',
#  'a',
#  'brilliant',
#  'professor,',
#  'and',
#  'another',
#  'fig',
#  'was',
#  'Ee',
#  'Gee,',
#  'the',
#  'amazing',
#  'editor,',
#  'and',
#  'another',
#  'fig',
#  'was',
#  'Europe',
#  'and',
#  'Africa',
#  'and',
#  'South',
#  'America,',
#  'and',
#  'another',
#  'fig',
#  'was',
#  'Constantin',
#  'and',
#  'Socrates',
#  'and',
#  'Attila',
#  'and',
#  'a',
# ...

# %% [markdown]
# # classical asymmetry

# %%
current_index = 0
new_line_indices = [1,11,14,16]
item_index = 0

line_text = ""

for item in longwords:

    if item[0].lower() == seed[current_index]:
#         print("found first letter in seed")
        line_text += item
        line_text += " "
        current_index += 1
    
    if current_index in new_line_indices:
#         print("item index in new line indices")
        print(line_text)
        line_text=""
        
    if current_index > len(seed) - 1:
#         print("current index got too big")
        print(line_text)
#         print(current_index)
        break

    item_index += 1
# Out:
# a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# being on the to overnight Mirage-grey like eggs seeing soon
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plate-glass I to
#
#
#
#
# of fat
#
#
#
#
#
# some ends
#
#
#
#
# like from
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# like of and the hullabaloo. in New gave

# %% [markdown]
# a
#
# being on the to overnight Mirage-grey like eggs seeing soon
#
# plate-glass I to
#
# of fat
#
# some ends like from like of and the hullabaloo. in New gave

# %%
longwords[10][0]
# Out:
# 't'

# %%
longwords
# Out:
# ['It',
#  'was',
#  'a',
#  'queer,',
#  'sultry',
#  'summer,',
#  'the',
#  'summer',
#  'they',
#  'electrocuted',
#  'the',
#  'Rosenbergs,',
#  'and',
#  'I',
#  "didn't",
#  'know',
#  'what',
#  'I',
#  'was',
#  'doing',
#  'in',
#  'New',
#  'York.',
#  "I'm",
#  'stupid',
#  'about',
#  'executions.',
#  'The',
#  'idea',
#  'of',
#  'being',
#  'electrocuted',
#  'makes',
#  'me',
#  'sick,',
#  'and',
#  "that's",
#  'all',
#  'there',
#  'was',
#  'to',
#  'read',
#  'about',
#  'in',
#  'the',
#  'papers—goggle-eyed',
#  'headlines',
#  'staring',
#  'up',
#  'at',
#  'me',
#  'on',
#  'every',
#  'street',
#  'corner',
#  'and',
#  'at',
#  'the',
#  'fusty,',
#  'peanut-smelling',
#  'mouth',
#  'of',
#  'every',
#  'subway.',
#  'It',
#  'had',
#  'nothing',
#  'to',
#  'do',
#  'with',
#  'me,',
#  'but',
#  'I',
#  "couldn't",
#  'help',
#  'wondering',
#  'what',
#  'it',
#  'would',
#  'be',
#  'like,',
#  'being',
#  'burned',
#  'alive',
#  'all',
#  'along',
# ...

# %%
one = longwords[1:6]
one_result = ' '.join(one)
one_result
# Out:
# 'was a queer, sultry summer,'

# %% [markdown]
# ### short text is not long enough

# %%
current_index = 0
for item in shortwords:
    if item[0].lower() == seed[current_index]:
        print(item , end=" ")
        current_index += 1
    if current_index > len(seed) - 1:
        break
# Out:
# a beckoned One the these out. myself losing

# %% [markdown]
# # indexed assymetry

# %%
for i, ch in enumerate(seed):
    print(i, ch)
    all_words_that_start_with = [item for item in shortwords if item[0].lower() == ch]
    print(all_words_that_start_with[i])
# Out:
# 0 a
# a
# 1 b
# before
# 2 o
# One
# 3 t
# the
# 4 t
# tip
# 5 o
# offbeat
# 6 m
# make
# 7 l
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-139-bfc371913184> in <module>
#       2     print(i, ch)
#       3     all_words_that_start_with = [item for item in shortwords if item[0].lower() == ch]
# ----> 4     print(all_words_that_start_with[i])
#
# IndexError: list index out of range

# %% [markdown]
# # vector proximity phonetically

# %%
import random
from collections import defaultdict
import numpy as np
import spacy
from simpleneighbors import SimpleNeighbors
