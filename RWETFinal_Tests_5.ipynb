# %%
import annoy

# %%
import random

# %%
import numpy as np

# %%
import json

# %%
import spacy
import en_core_web_md

# %%
from simpleneighbors import SimpleNeighbors

# %%
from collections import Counter

# %%
import markovify

# %%
import tracery

# %%
from tracery.modifiers import base_english

# %%
import pronouncing as pr

# %%
nlp = spacy.load('en_core_web_md')

# %%
text = open("tongues_1.txt").read()

# %%
doc = nlp(text)

# %%
nouns = [item.text for item in doc if item.tag_ == 'NN']

# %%
verbs = [item.text for item in doc if item.tag_ == 'VBD']

# %%
prnouns = [item.text for item in doc if item.tag_ == 'PRP']

# %%
adjs = [item.text for item in doc if item.tag_ == 'JJ']

# %%
nouns
# Out:
# ['voice',
#  'voice',
#  'place',
#  'voice',
#  'childhood',
#  'college',
#  'taste',
#  'port',
#  'fact',
#  'case',
#  'climbing',
#  'time',
#  'voice',
#  'voice',
#  'person',
#  'lesson',
#  'example',
#  'class',
#  'way',
#  'cowardice',
#  'eagerness',
#  'swap',
#  'voice',
#  'childhood',
#  'story',
#  'synthesis',
#  'district',
#  'way',
#  'way',
#  'kind',
#  'knowledge',
#  'kind',
#  'while',
#  'home',
#  'voice',
#  'voice',
#  'college',
#  'vice',
#  'sort',
#  'wonder',
#  'flexibility',
#  'thing',
#  'flexibility',
#  'something',
#  'work',
#  'voice',
#  'one',
#  'world',
#  'work',
#  'class',
#  'sea',
#  'pond',
#  'world',
#  'puddle',
#  'voice',
#  'way',
#  'garment',
#  'college',
#  'gown',
#  'voice',
#  'mouth',
#  'part',
#  'culture',
#  'preface',
#  'play',
#  'tongue',
#  'Voice',
#  'adaptation',
#  'sin',
#  'Monitoring',
#  'pastime',
#  'sex',
#  'libel',
#  'sell',
#  'out',
#  'style',
#  'something',
#  'parmigiano',
# ...

# %%
verbs
# Out:
# ['picked',
#  'thought',
#  'was',
#  'did',
#  'stood',
#  'went',
#  'did',
#  'had',
#  'occurred',
#  'was',
#  'thought',
#  'was',
#  'had',
#  'was',
#  'spoke',
#  'seemed',
#  'felt',
#  'was',
#  'was',
#  'picked',
#  'put',
#  'were',
#  'put',
#  'acquired',
#  'represented',
#  'meant',
#  'wrote',
#  'was',
#  'heard',
#  'Did',
#  'heard',
#  'was',
#  'spoke',
#  'tried',
#  'was',
#  'told',
#  'was',
#  '—disguised',
#  'got',
#  'sacrificed',
#  'had',
#  'was',
#  'spoke',
#  'wrote',
#  'said',
#  'got',
#  'thought',
#  'were',
#  'was',
#  'said',
#  'fulfilled',
#  'was',
#  'thought',
#  'left',
#  'occupied',
#  'had',
#  'did',
#  'became',
#  'happened',
#  'subjected',
#  'came',
#  'came',
#  'seemed',
#  'said',
#  'was',
#  'was',
#  'was',
#  'was',
#  'was',
#  'did',
#  'was',
#  'had',
#  'was',
#  'latched',
#  'underestimated',
#  'was',
#  'did',
#  'spoke',
#  'succeeded',
#  'did',
#  'was',
#  'had',
#  'kept',
#  'heard',
#  'had',
# ...

# %%
prnouns
# Out:
# ['I',
#  'I',
#  'it',
#  'it',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'it',
#  'It',
#  'me',
#  'I',
#  'I',
#  'I',
#  'I',
#  'it',
#  'I',
#  'I',
#  'I',
#  'it',
#  'me',
#  'me',
#  'I',
#  'I',
#  'I',
#  'it',
#  'I',
#  'it',
#  'I',
#  'it',
#  'I',
#  'They',
#  'me',
#  'it',
#  'it',
#  'it',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'him',
#  'he',
#  'We',
#  'we',
#  'They',
#  'it',
#  'me',
#  'me',
#  'them',
#  'I',
#  'he',
#  'It',
#  'He',
#  'she',
#  'you',
#  'You',
#  'I',
#  'you',
#  'him',
#  'I',
#  'we',
#  'He',
#  'him',
#  'I',
#  'him',
#  'I',
#  'I',
#  'you',
#  'you',
#  'I',
#  'I',
#  'em',
#  'I',
#  'they',
#  'me',
#  'I',
#  'she',
#  'I',
#  'I',
#  'it',
#  'I',
#  'it',
#  'I',
#  'me',
#  'I',
#  'her',
#  'it',
#  'You',
#  'me',
#  'you',
#  'it',
#  'I',
#  'I',
#  'she',
#  'she',
#  'he',
#  'he',
#  'themselves',
#  'they',
#  'them',
#  'It',
#  'we',
#  'them',
#  'itself',
#  'he',
#  'he',
# ...

# %%
adjs
# Out:
# ['English',
#  'rounded',
#  'right',
#  'unabridged',
#  'bald',
#  'social',
#  'firm',
#  'useful',
#  'same',
#  'other',
#  'constitutional',
#  'straight',
#  'own',
#  'disparate',
#  'new',
#  'old',
#  'new',
#  'different',
#  'old',
#  'old',
#  'alive',
#  'double',
#  'single',
#  'big',
#  'colorful',
#  'posher',
#  'univocal',
#  'literary',
#  'exotic',
#  'only',
#  'alive',
#  'many',
#  'native',
#  'new',
#  'Few',
#  'original',
#  'British',
#  'such',
#  'national',
#  'popular',
#  'European',
#  'original',
#  'innocent',
#  '“',
#  'British',
#  'mockney',
#  'public',
#  'other',
#  'unforgivable',
#  'unchanging',
#  'singular',
#  'different',
#  'different',
#  'faced',
#  'very',
#  'tragic',
#  '“',
#  'own',
#  'true',
#  'hot',
#  'middling',
#  'posh',
#  'redolent',
#  'tragically',
#  'worthy',
#  'first',
#  'didactic',
#  'didactic',
#  'determined',
#  'unambiguous',
#  'saucy',
#  'proud',
#  'good',
#  'genteel',
#  'Last',
#  'old',
# ...

# %%
rules = {
        "origin": ["Hello.\n#prnouns# #verbs# #adjs# #nouns#\n#prnouns# #verbs# #adjs# #nouns#\n#prnouns# #verbs# #adjs# #nouns#\n#prnouns# #verbs# #adjs# #nouns#\n#prnouns# #verbs# #adjs# #nouns#\n#prnouns# #verbs# #adjs# #nouns#\n#prnouns# #verbs# #adjs# #nouns#\n#prnouns# #verbs# #adjs# #nouns#\n#prnouns# #verbs# #adjs# #nouns#\n#prnouns# #verbs# #adjs# #nouns#"],
        "prnouns": prnouns, 
        "verbs": verbs,
        "adjs": adjs,
        "nouns": nouns,
}
grammar = tracery.Grammar(rules)
print(grammar.flatten("#origin#"))
# Out:
# Hello.
# itself got different altar
# I possessed clear character
# they oversaw impressive mother
# you put tragic art
# we meant varied novelist
# we banished personal truth
# he won interim stage
# I was postracial disease
# it set correct voice
# you was good college

# %% [markdown]
# APPLE #ALLCAPS
#
# Apple plum, carpet steak, seed clam, colored wine, calm seen, cold cream, best shake, potato, potato and no no gold work with pet, a green seen is called bake and change sweet is bready, a little piece a little piece please.
# #adjs#noun#,#adjs#noun#,#adjs#noun#,#adjs#noun#,#adjs#noun#,#adjs#noun#,#adjs#noun#,
# #prnouns# #verbs# #adjs# #nouns#
# #prnouns# #verbs# #adjs# #nouns#
#
# A little piece please. Cane again to the presupposed and ready eucalyptus tree, count out sherry and ripe plates and little corners of a kind of ham. This is use.

# %%
rules = {
        "origin": ["VOICE.\n\n#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#prnouns# #verbs# #adjs# #nouns# #prnouns# #verbs# #adjs# #nouns#"],
        "prnouns": prnouns, 
        "verbs": verbs,
        "adjs": adjs,
        "nouns": nouns,
}
grammar = tracery.Grammar(rules)
print(grammar.flatten("#origin#"))
# Out:
# VOICE.
#
# many voice,single set,ugly age,didactic anxiety,impassioned delight,own world,Protestant business,you was American idea it had initial life

# %%
rules = {
        "number_1": ["VOICE.\n\n#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#\n#prnouns# #verbs# #adjs# #nouns# #prnouns# #verbs# #adjs# #nouns#.\n\n"],
        "number_2": ["IDENTITY.\n\n#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#\n#prnouns# #verbs# #adjs# #nouns# #prnouns# #verbs# #adjs# #nouns#.\n\n"],
        "number_3": ["COWARDICE.\n\n#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#,#adjs# #nouns#\n#prnouns# #verbs# #adjs# #nouns# #prnouns# #verbs# #adjs# #nouns#.\n\n"],
        "prnouns": prnouns, 
        "verbs": verbs,
        "adjs": adjs,
        "nouns": nouns,
}
grammar = tracery.Grammar(rules)
print(grammar.flatten("#number_1#"))
print(grammar.flatten("#number_2#"))
print(grammar.flatten("#number_3#"))
# Out:
# VOICE.
#
# fancy empathy,intellectual Patriotism,double party,key corner,European equivocation,liberal addition,audacious choice
# she picked certain evolution he lived many west.
#
#
# IDENTITY.
#
# genuine quality,hard rood,irreducible singular,individual heroism,new face,activist antidote,present community
# me said melancholy president I had lovely place.
#
#
# COWARDICE.
#
# crazy character,American love,own culture,sure version,white family,political force,constitutional father
# themselves rang proud delight themselves was undercut I.
