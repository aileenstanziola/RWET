# %%
words_ft = open("figtree.txt").read().split()

# %%
seed = 'abottomlesspitofselfloathing'

# %%
import random

# %%
for ch in seed:
    matches = [word for word in words if word.startswith(ch)]
    print(random.choice(matches))
# Out:
# above
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-d7f0d1f90bff> in <module>
#       1 for ch in seed:
#       2     matches = [word for word in words if word.startswith(ch)]
# ----> 3     print(random.choice(matches))
#
# /anaconda3/lib/python3.7/random.py in choice(self, seq)
#     259             i = self._randbelow(len(seq))
#     260         except ValueError:
# --> 261             raise IndexError('Cannot choose from an empty sequence') from None
#     262         return seq[i]
#     263
#
# IndexError: Cannot choose from an empty sequence

# %%
a_words_ft = [item for item in words_ft if item.lower().startswith('a')]
b_words_ft = [item for item in words_ft if item.lower().startswith('b')]
o_words_ft = [item for item in words_ft if item.lower().startswith('o')]
t_words_ft = [item for item in words_ft if item.lower().startswith('t')]
m_words_ft = [item for item in words_ft if item.lower().startswith('m')]
l_words_ft = [item for item in words_ft if item.lower().startswith('l')]
e_words_ft = [item for item in words_ft if item.lower().startswith('e')]
s_words_ft = [item for item in words_ft if item.lower().startswith('s')]
p_words_ft = [item for item in words_ft if item.lower().startswith('p')]
i_words_ft = [item for item in words_ft if item.lower().startswith('i')]
f_words_ft = [item for item in words_ft if item.lower().startswith('f')]
h_words_ft = [item for item in words_ft if item.lower().startswith('h')]
n_words_ft = [item for item in words_ft if item.lower().startswith('n')]
g_words_ft = [item for item in words_ft if item.lower().startswith('g')]

# %%
a_words_ft
# Out:
# ['a',
#  'a',
#  'and',
#  'a',
#  'and',
#  'a',
#  'and',
#  'and',
#  'another',
#  'a',
#  'and',
#  'another',
#  'a',
#  'and',
#  'another',
#  'amazing',
#  'and',
#  'another',
#  'and',
#  'Africa',
#  'and',
#  'America,',
#  'and',
#  'another',
#  'and',
#  'and',
#  'Attila',
#  'and',
#  'a',
#  'and',
#  'and',
#  'another',
#  'an',
#  'and',
#  'and',
#  'above',
#  'and',
#  'all',
#  'and,',
#  'as',
#  'and',
#  'and,',
#  'at']

# %%
b_words_ft
# Out:
# ['branching',
#  'before',
#  'branch,',
#  'beckoned',
#  'brilliant',
#  'beyond',
#  'because',
#  'but',
#  'began',
#  'black,',
#  'by']

# %%
o_words_ft
# Out:
# ['out',
#  'of',
#  'One',
#  'of',
#  'other',
#  'offbeat',
#  'Olympic',
#  'out.',
#  'of',
#  'of',
#  'one',
#  'of',
#  'one',
#  'one',
#  'one,']

# %%
t_words_ft
# Out:
# ['the',
#  'tree',
#  'the',
#  'the',
#  'tip',
#  'the',
#  'these',
#  'the',
#  'this',
#  'tree,',
#  'to',
#  'the',
#  'them,',
#  'the',
#  'there,',
#  'to',
#  'the',
#  'to',
#  'they',
#  'to',
#  'the']

# %%
m_words_ft
# Out:
# ['my',
#  'me',
#  'many',
#  'more',
#  'make',
#  'myself',
#  'make',
#  'my',
#  'mind',
#  'meant',
#  'my']

# %%
l_words_ft
# Out:
# ['life', 'like', 'like', 'lovers', 'lady', 'losing']

# %%
e_words_ft
# Out:
# ['every', 'Ee', 'editor,', 'Europe', 'each', 'every']

# %%
s_words_ft
# Out:
# ['saw', 'story.', 'South', 'Socrates', 'saw', 'sitting', 'starving', 'sat']

# %%
p_words_ft
# Out:
# ['purple', 'poet', 'professor,', 'pack', 'professions,', 'plopped']

# %%
i_words_ft
# Out:
# ['I', 'in', 'I', 'I', 'in', 'I', 'I', 'I', 'I']

# %%
t_words_ft
# Out:
# ['the',
#  'tree',
#  'the',
#  'the',
#  'tip',
#  'the',
#  'these',
#  'the',
#  'this',
#  'tree,',
#  'to',
#  'the',
#  'them,',
#  'the',
#  'there,',
#  'to',
#  'the',
#  'to',
#  'they',
#  'to',
#  'the']

# %%
f_words_ft
# Out:
# ['fig',
#  'From',
#  'fat',
#  'fig,',
#  'future',
#  'fig',
#  'fig',
#  'famous',
#  'fig',
#  'fig',
#  'fig',
#  'fig',
#  'fig',
#  'figs',
#  'figs',
#  'fig',
#  'figs',
#  'figs',
#  'feet.']

# %%
h_words_ft
# Out:
# ['husband', 'happy', 'home']

# %%
n_words_ft
# Out:
# ['names']

# %%
g_words_ft
# Out:
# ['green', 'Gee,', 'go', 'ground']

# %%
print(random.choice(a_words_ft))
print(random.choice(b_words_ft))
print(random.choice(o_words_ft))
print(random.choice(t_words_ft))
print(random.choice(t_words_ft))
print(random.choice(o_words_ft))
print(random.choice(m_words_ft))
print(random.choice(l_words_ft))
print(random.choice(e_words_ft))
print(random.choice(s_words_ft))
print(random.choice(s_words_ft))
print(random.choice(p_words_ft))
print(random.choice(i_words_ft))
print(random.choice(t_words_ft))
print(random.choice(o_words_ft))
print(random.choice(f_words_ft))
print(random.choice(s_words_ft))
print(random.choice(e_words_ft))
print(random.choice(l_words_ft))
print(random.choice(f_words_ft))
print(random.choice(l_words_ft))
print(random.choice(o_words_ft))
print(random.choice(a_words_ft))
print(random.choice(t_words_ft))
print(random.choice(h_words_ft))
print(random.choice(i_words_ft))
print(random.choice(n_words_ft))
print(random.choice(g_words_ft))
# Out:
# and
# beyond
# out.
# there,
# there,
# offbeat
# make
# life
# every
# sat
# saw
# purple
# I
# to
# one
# famous
# South
# every
# life
# fig
# losing
# of
# a
# the
# happy
# in
# names
# go

# %%
initials = {}
for item in words:
    first_let = item[0]
    if first_let in initials:
        initials[first_let].append(item)
    else: 
        initials[first_let] = []
        initials[first_let].append(item)

# %%
initials
# Out:
# {'I': ['I', 'I', 'I', 'I', 'I', 'I', 'I'],
#  's': ['saw', 'story.', 'saw', 'sitting', 'starving', 'sat'],
#  'm': ['my',
#   'me',
#   'many',
#   'more',
#   'make',
#   'myself',
#   'make',
#   'my',
#   'mind',
#   'meant',
#   'my'],
#  'l': ['life', 'like', 'like', 'lovers', 'lady', 'losing'],
#  'b': ['branching',
#   'before',
#   'branch,',
#   'beckoned',
#   'brilliant',
#   'beyond',
#   'because',
#   'but',
#   'began',
#   'black,',
#   'by'],
#  'o': ['out',
#   'of',
#   'of',
#   'other',
#   'offbeat',
#   'out.',
#   'of',
#   'of',
#   'one',
#   'of',
#   'one',
#   'one',
#   'one,'],
#  't': ['the',
#   'tree',
#   'the',
#   'the',
#   'tip',
#   'the',
#   'these',
#   'the',
#   'this',
#   'tree,',
#   'to',
#   'the',
#   'them,',
#   'the',
#   'there,',
#   'to',
#   'the',
#   'to',
#   'they',
#   'to',
#   'the'],
#  'g': ['green', 'go', 'ground'],
#  'f': ['fig',
#   'fat',
#   'fig,',
#   'future',
#   'fig',
#   'fig',
#   'famous',
#   'fig',
# ...

# %%
for ch in seed:
    print(random.choice(initials[ch]).capitalize())
# Out:
# A
# Branching
# Of
# The
# The
# Of
# My
# Like
# Each
# Saw
# Sat
# Purple
# In
# Them,
# One
# Figs
# Story.
# Every
# Losing
# Fat
# Lady
# One
# Another
# The
# Happy
# In
# Names
# Green

# %%
print ('\n'.join([random.choice(initials[ch])for ch in seed]))
# Out:
# and
# before
# out
# they
# the
# out
# me
# like
# every
# starving
# starving
# pack
# in
# tip
# out
# fig
# sitting
# every
# life
# famous
# like
# out
# and
# to
# husband
# in
# names
# go

# %%
words_wr = open("white_rabbit.txt").read().split()

# %%
a_words_wr = [item for item in words_wr if item.lower().startswith('a')]
b_words_wr = [item for item in words_wr if item.lower().startswith('b')]
o_words_wr = [item for item in words_wr if item.lower().startswith('o')]
t_words_wr = [item for item in words_wr if item.lower().startswith('t')]
m_words_wr = [item for item in words_wr if item.lower().startswith('m')]
l_words_wr = [item for item in words_wr if item.lower().startswith('l')]
e_words_wr = [item for item in words_wr if item.lower().startswith('e')]
s_words_wr = [item for item in words_wr if item.lower().startswith('s')]
p_words_wr = [item for item in words_wr if item.lower().startswith('p')]
i_words_wr = [item for item in words_wr if item.lower().startswith('i')]
f_words_wr = [item for item in words_wr if item.lower().startswith('f')]
h_words_wr = [item for item in words_wr if item.lower().startswith('h')]
n_words_wr = [item for item in words_wr if item.lower().startswith('n')]
g_words_wr = [item for item in words_wr if item.lower().startswith('g')]

# %%
words_hm = open("kafka_onthe_shore.txt").read().split()

# %%
a_words_hm = [item for item in words_hm if item.lower().startswith('a')]
b_words_hm = [item for item in words_hm if item.lower().startswith('b')]
o_words_hm = [item for item in words_hm if item.lower().startswith('o')]
t_words_hm = [item for item in words_hm if item.lower().startswith('t')]
m_words_hm = [item for item in words_hm if item.lower().startswith('m')]
l_words_hm = [item for item in words_hm if item.lower().startswith('l')]
e_words_hm = [item for item in words_hm if item.lower().startswith('e')]
s_words_hm = [item for item in words_hm if item.lower().startswith('s')]
p_words_hm = [item for item in words_hm if item.lower().startswith('p')]
i_words_hm = [item for item in words_hm if item.lower().startswith('i')]
f_words_hm = [item for item in words_hm if item.lower().startswith('f')]
h_words_hm = [item for item in words_hm if item.lower().startswith('h')]
n_words_hm = [item for item in words_hm if item.lower().startswith('n')]
g_words_hm = [item for item in words_hm if item.lower().startswith('g')]

# %%
a_words = "a_words_ft + a_words_wr + a_words_hm"
b_words = ("b_words_ft" + "b_words_wr" + "b_words_hm")
o_words = ("o_words_ft" + "o_words_wr" + "o_words_hm")
t_words = ("t_words_ft" + "t_words_wr" + "t_words_hm")
m_words = ("m_words_ft" + "m_words_wr" + "m_words_hm")
l_words = ("l_words_ft" + "l_words_wr" + "l_words_hm")
e_words = ("e_words_ft" + "e_words_wr" + "e_words_hm")
s_words = ("s_words_ft" + "s_words_wr" + "s_words_hm")
p_words = ("p_words_ft" + "p_words_wr" + "p_words_hm")
i_words = ("i_words_ft" + "i_words_wr" + "i_words_hm")
f_words = ("f_words_ft" + "f_words_wr" + "f_words_hm")
h_words = ("h_words_ft" + "h_words_wr" + "h_words_hm")
n_words = ("n_words_ft" + "n_words_wr" + "n_words_hm")
g_words = ("g_words_ft" + "g_words_wr" + "g_words_hm")

# %%
a_words
# Out:
# 'a_words_ft + a_words_wr + a_words_hm'

# %%
import tracery
from tracery.modifiers import base_english

# %%
rules = {
        "origin": "#a_words# #b_words# #o_words# #t_words# #t_words# #o_words# #m_words# #l_words# #e_words# #s_words# #s_words# #p_words# #i_words# #t_words# #o_words# #f_words# #s_words# #e_words# #l_words# #f_words# #l_words# #o_words# #a_words# #t_words# #h_words# #i_words# #n_words# #g_words#."
    ,
        "a_words": a_words, 
        "b_words": b_words,
        "o_words": o_words,
        "t_words": t_words,
        "m_words": m_words,
        "l_words": l_words,
        "e_words": e_words,
        "s_words": s_words,
        "p_words": p_words, 
        "i_words": i_words,
        "f_words": f_words,
        "h_words": h_words,
        "n_words": n_words,
        "g_words": g_words
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
print(grammar.flatten("#origin#"+"\n"+"#origin#"+"\n""#origin#"+"\n"+"#origin#"+"\n""#origin#"+"\n"+"#origin#"+"\n"))
# Out:
# a_words_fta_words_wra_words_hm b_words_ftb_words_wrb_words_hm o_words_fto_words_wro_words_hm t_words_ftt_words_wrt_words_hm t_words_ftt_words_wrt_words_hm o_words_fto_words_wro_words_hm m_words_ftm_words_wrm_words_hm l_words_ftl_words_wrl_words_hm e_words_fte_words_wre_words_hm s_words_fts_words_wrs_words_hm s_words_fts_words_wrs_words_hm p_words_ftp_words_wrp_words_hm i_words_fti_words_wri_words_hm t_words_ftt_words_wrt_words_hm o_words_fto_words_wro_words_hm f_words_ftf_words_wrf_words_hm s_words_fts_words_wrs_words_hm e_words_fte_words_wre_words_hm l_words_ftl_words_wrl_words_hm f_words_ftf_words_wrf_words_hm l_words_ftl_words_wrl_words_hm o_words_fto_words_wro_words_hm a_words_fta_words_wra_words_hm t_words_ftt_words_wrt_words_hm h_words_fth_words_wrh_words_hm i_words_fti_words_wri_words_hm n_words_ftn_words_wrn_words_hm g_words_ftg_words_wrg_words_hm.
# ...

# %%
words_ft = open("figtree.txt").read().split() # read in a text file, split into words
initials_ft = {} # create an empty dictionary

for item in words_ft: # run this code for every word in the text
    
    first_let = item[0] # first_let now has the first character of the string
    
    # check to see if the letter is already a key in the dictionary.
    # if not, add a new key/value pair with an empty list as the value.
    if first_let not in initials_ft:
        initials_ft[first_let] = []
        
    # append the current word to the list that is the value for this key
    initials_ft[first_let].append(item)
    
    # uncomment line below to see debug output
    print(item, first_let, initials_ft[first_let])
# Out:
# I I ['I']
# saw s ['saw']
# my m ['my']
# life l ['life']
# branching b ['branching']
# out o ['out']
# before b ['branching', 'before']
# me m ['my', 'me']
# like l ['life', 'like']
# the t ['the']
# green g ['green']
# fig f ['fig']
# tree t ['the', 'tree']
# in i ['in']
# the t ['the', 'tree', 'the']
# story. s ['saw', 'story.']
# From F ['From']
# the t ['the', 'tree', 'the', 'the']
# tip t ['the', 'tree', 'the', 'the', 'tip']
# of o ['out', 'of']
# every e ['every']
# branch, b ['branching', 'before', 'branch,']
# like l ['life', 'like', 'like']
# a a ['a']
# fat f ['fig', 'fat']
# purple p ['purple']
# fig, f ['fig', 'fat', 'fig,']
# a a ['a', 'a']
# wonderful w ['wonderful']
# future f ['fig', 'fat', 'fig,', 'future']
# beckoned b ['branching', 'before', 'branch,', 'beckoned']
# and a ['a', 'a', 'and']
# winked. w ['wonderful', 'winked.']
# One O ['One']
# fig f ['fig', 'fat', 'fig,', 'future', 'fig']
# was w ['wonderful', 'winked.', 'was']
# a a ['a', 'a', 'and', 'a']
# ...

# %%
words_wr = open("white_rabbit.txt").read().split() # read in a text file, split into words
initials_wr = {} # create an empty dictionary

for item in words_wr: # run this code for every word in the text
    
    first_let = item[0] # first_let now has the first character of the string
    
    # check to see if the letter is already a key in the dictionary.
    # if not, add a new key/value pair with an empty list as the value.
    if first_let not in initials_wr:
        initials_wr[first_let] = []
        
    # append the current word to the list that is the value for this key
    initials_wr[first_let].append(item)
    
    # uncomment line below to see debug output
    print(item, first_let, initials_wr[first_let])
# Out:
# One O ['One']
# pill p ['pill']
# makes m ['makes']
# you y ['you']
# larger l ['larger']
# and a ['and']
# one o ['one']
# pill p ['pill', 'pill']
# makes m ['makes', 'makes']
# you y ['you', 'you']
# small, s ['small,']
# and a ['and', 'and']
# the t ['the']
# ones o ['one', 'ones']
# that t ['the', 'that']
# mother m ['makes', 'makes', 'mother']
# gives g ['gives']
# you y ['you', 'you', 'you']
# don't d ["don't"]
# do d ["don't", 'do']
# anything a ['and', 'and', 'anything']
# at a ['and', 'and', 'anything', 'at']
# all. a ['and', 'and', 'anything', 'at', 'all.']
# Go G ['Go']
# ask a ['and', 'and', 'anything', 'at', 'all.', 'ask']
# Alice, A ['Alice,']
# when w ['when']
# she's s ['small,', "she's"]
# ten t ['the', 'that', 'ten']
# feet f ['feet']
# tall. t ['the', 'that', 'ten', 'tall.']
# And A ['Alice,', 'And']
# if i ['if']
# you y ['you', 'you', 'you', 'you']
# go g ['gives', 'go']
# chasing c ['chasing']
# rabbits, r ['rabbits,']
# ...

# %%
words_hm = open("kafka_onthe_shore.txt").read().split() # read in a text file, split into words
initials_hm = {} # create an empty dictionary

for item in words_hm: # run this code for every word in the text
    
    first_let = item[0] # first_let now has the first character of the string
    
    # check to see if the letter is already a key in the dictionary.
    # if not, add a new key/value pair with an empty list as the value.
    if first_let not in initials_hm:
        initials_hm[first_let] = []
        
    # append the current word to the list that is the value for this key
    initials_hm[first_let].append(item)
    
    # uncomment line below to see debug output
    print(item, first_let, initials_hm[first_let])
# Out:
# Sometimes S ['Sometimes']
# fate f ['fate']
# is i ['is']
# like l ['like']
# a a ['a']
# small s ['small']
# sandstorm s ['small', 'sandstorm']
# that t ['that']
# keeps k ['keeps']
# changing c ['changing']
# directions. d ['directions.']
# You Y ['You']
# change c ['changing', 'change']
# direction d ['directions.', 'direction']
# but b ['but']
# the t ['that', 'the']
# sandstorm s ['small', 'sandstorm', 'sandstorm']
# chases c ['changing', 'change', 'chases']
# you. y ['you.']
# You Y ['You', 'You']
# turn t ['that', 'the', 'turn']
# again, a ['a', 'again,']
# but b ['but', 'but']
# the t ['that', 'the', 'turn', 'the']
# storm s ['small', 'sandstorm', 'sandstorm', 'storm']
# adjusts. a ['a', 'again,', 'adjusts.']
# Over O ['Over']
# and a ['a', 'again,', 'adjusts.', 'and']
# over o ['over']
# you y ['you.', 'you']
# play p ['play']
# this t ['that', 'the', 'turn', 'the', 'this']
# out, o ['over', 'out,']
# like l ['like', 'like']
# ...

# %%
for let in "abottomlesspitofselfloathing":
    word = random.choice(initials_ft[let])
    print(word.capitalize())
# Out:
# Another
# Brilliant
# Out.
# The
# The
# Out
# Mind
# Lovers
# Every
# Sitting
# Story.
# Pack
# In
# The
# Offbeat
# Figs
# Starving
# Every
# Lady
# Fig
# Lady
# Of
# And
# To
# Husband
# In
# Names
# Ground

# %%
for let in "abottomlesspitofselfloathing":
    if let in initials_wr:
        word = random.choice(initials_wr[let])
        print(word.capitalize())
    else:
        print(">>> WARNING! ACROSTIC FAILURE! WARNING")
# Out:
# And
# Backwards
# One
# Ten
# The
# Off
# Mother
# Larger
# >>> WARNING! ACROSTIC FAILURE! WARNING
# Said:
# She'll
# Pill
# Is
# The
# Of
# Fallen
# She
# >>> WARNING! ACROSTIC FAILURE! WARNING
# Logic
# Fallen
# Larger
# Off
# Anything
# That
# Had
# Is
# >>> WARNING! ACROSTIC FAILURE! WARNING
# Given

# %%
for let in "abottomlesspitofselfloathing":
    word = random.choice(initials_hm[let])
    print(word.capitalize())
# Out:
# Away,
# But
# Of
# The
# The
# Of
# Mistake
# Like
# Ears
# Storm
# Sandstorm
# Plugging
# Is
# Through,
# Of
# Fine
# Storm
# Eyes
# Like
# Fact,
# Like
# Over.
# A
# To
# How
# Is
# Need
# Give

# %%
from collections import defaultdict

# %%
initials_wr = defaultdict(list)

# %%
for let in "abottomlesspitofselfloathing":
    word = random.choice(initials_hm[let])
    print(word.capitalize())
# Out:
# A
# Before
# Ominous
# The
# Through
# Over.
# Might
# Like
# Ears
# Storm's
# Sand
# Plugging
# It
# That
# Of
# Fate
# Symbolic
# Ears
# Like
# Fine
# Like
# Over.
# And
# Turn
# Has
# Is
# No
# Give

# %%
words_bj = open("the_bell_jar.txt").read().split() # read in a text file, split into words
initials_bj = {} # create an empty dictionary

for item in words_bj: # run this code for every word in the text
    
    first_let = item[0] # first_let now has the first character of the string
    
    # check to see if the letter is already a key in the dictionary.
    # if not, add a new key/value pair with an empty list as the value.
    if first_let not in initials_bj:
        initials_bj[first_let] = []
        
    # append the current word to the list that is the value for this key
    initials_bj[first_let].append(item)
    
    # uncomment line below to see debug output
    print(item, first_let, initials_bj[first_let])
# Out:
# It I ['It']
# was w ['was']
# a a ['a']
# queer, q ['queer,']
# sultry s ['sultry']
# summer, s ['sultry', 'summer,']
# the t ['the']
# summer s ['sultry', 'summer,', 'summer']
# they t ['the', 'they']
# electrocuted e ['electrocuted']
# the t ['the', 'they', 'the']
# Rosenbergs, R ['Rosenbergs,']
# and a ['a', 'and']
# I I ['It', 'I']
# didn't d ["didn't"]
# know k ['know']
# what w ['was', 'what']
# I I ['It', 'I', 'I']
# was w ['was', 'what', 'was']
# doing d ["didn't", 'doing']
# in i ['in']
# New N ['New']
# York. Y ['York.']
# I'm I ['It', 'I', 'I', "I'm"]
# stupid s ['sultry', 'summer,', 'summer', 'stupid']
# about a ['a', 'and', 'about']
# executions. e ['electrocuted', 'executions.']
# The T ['The']
# idea i ['in', 'idea']
# of o ['of']
# being b ['being']
# electrocuted e ['electrocuted', 'executions.', 'electrocuted']
# makes m ['makes']
# me m ['makes', 'me']
# sick, s ['sultry', 'summer,', 'summer', 'stupid', 'sick,']
# and a ['a', 'and', 'about', 'and']
# ...

# %%
for let in "abottomlesspitofselfloathing":
    word = random.choice(initials_bj[let])
    print(word.capitalize())
# Out:
# A
# Beside
# On,
# The
# The
# Off
# My
# Little
# Expression—and
# Something
# Sepulchral
# Pink
# It.
# The
# One
# Fifty
# Said.
# Express
# Lawyer
# Fine,
# Long,
# Others
# And
# The
# Head
# Idioms,
# Name
# Glasses

# %%
words_bj = open("the_bell_jar.txt").read().split()

# %%
words_bj
# Out:
# ['It',
#  'was',
#  'a',
#  'queer,',
#  'sultry',
#  'summer,',
#  'the',
#  'summer',
#  'they',
#  'electrocuted',
#  'the',
#  'Rosenbergs,',
#  'and',
#  'I',
#  "didn't",
#  'know',
#  'what',
#  'I',
#  'was',
#  'doing',
#  'in',
#  'New',
#  'York.',
#  "I'm",
#  'stupid',
#  'about',
#  'executions.',
#  'The',
#  'idea',
#  'of',
#  'being',
#  'electrocuted',
#  'makes',
#  'me',
#  'sick,',
#  'and',
#  "that's",
#  'all',
#  'there',
#  'was',
#  'to',
#  'read',
#  'about',
#  'in',
#  'the',
#  'papers—goggle-eyed',
#  'headlines',
#  'staring',
#  'up',
#  'at',
#  'me',
#  'on',
#  'every',
#  'street',
#  'corner',
#  'and',
#  'at',
#  'the',
#  'fusty,',
#  'peanut-smelling',
#  'mouth',
#  'of',
#  'every',
#  'subway.',
#  'It',
#  'had',
#  'nothing',
#  'to',
#  'do',
#  'with',
#  'me,',
#  'but',
#  'I',
#  "couldn't",
#  'help',
#  'wondering',
#  'what',
#  'it',
#  'would',
#  'be',
#  'like,',
#  'being',
#  'burned',
#  'alive',
#  'all',
#  'along',
# ...

# %%
a_words_bj = [item for item in words_bj if item.lower().startswith('a')]
b_words_bj = [item for item in words_bj if item.lower().startswith('b')]
o_words_bj = [item for item in words_bj if item.lower().startswith('o')]
t_words_bj = [item for item in words_bj if item.lower().startswith('t')]
m_words_bj = [item for item in words_bj if item.lower().startswith('m')]
l_words_bj = [item for item in words_bj if item.lower().startswith('l')]
e_words_bj = [item for item in words_bj if item.lower().startswith('e')]
s_words_bj = [item for item in words_bj if item.lower().startswith('s')]
p_words_bj = [item for item in words_bj if item.lower().startswith('p')]
i_words_bj = [item for item in words_bj if item.lower().startswith('i')]
f_words_bj = [item for item in words_bj if item.lower().startswith('f')]
h_words_bj = [item for item in words_bj if item.lower().startswith('h')]
n_words_bj = [item for item in words_bj if item.lower().startswith('n')]
g_words_bj = [item for item in words_bj if item.lower().startswith('g')]

# %%
rules = {
        "origin": "#a_words#\n #b_words# #o_words# #t_words# #t_words# #o_words# #m_words# #l_words# #e_words# #s_words# #s_words#\n #p_words# #i_words# #t_words#\n #o_words# #f_words#\n #s_words# #e_words# #l_words# #f_words# - #l_words# #o_words# #a_words# #t_words# #h_words# #i_words# #n_words# #g_words#."
    ,
        "a_words": a_words_bj, 
        "b_words": b_words_bj,
        "o_words": o_words_bj,
        "t_words": t_words_bj,
        "m_words": m_words_bj,
        "l_words": l_words_bj,
        "e_words": e_words_bj,
        "s_words": s_words_bj,
        "p_words": p_words_bj, 
        "i_words": i_words_bj,
        "f_words": f_words_bj,
        "h_words": h_words_bj,
        "n_words": n_words_bj,
        "g_words": g_words_bj
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
print(grammar.flatten("#origin#"+"\n\n"+"#origin#"+"\n\n"+"#origin#"+"\n\n"+"#origin#"+"\n\n"+"#origin#"+"\n\n"+"#origin#"+"\n\n"))
# Out:
# a
#  beautiful office the the of my lifted every sleep. She
#  pear I to
#  often feel
#  swung, evil. letter Friday - little over as the he in nights, girl.
#
# an
#  bathtowel only They there on my like emotions salesmanship. seemed
#  pale I the
#  of followed
#  soft-boiled eggs loved furry - leather of about the had I new get.
#
# a
#  But on the the one miss letter eerily State. semester
#  published, I tiny
#  on flipped
#  see Esther.' level for - laughing. out Adirondacks. they had in nobly, ghostly,.
#
# a
#  back of the the of Mr Lenny Eve, show, see
#  purple-black in that
#  out first
#  so,' evasively. let father. - like of and the have I now go.
#
# any
#  Buddy of time to off my lay eyes so saw
#  professor in to
#  on first
#  school Every like fig-tree - looked of another the had in names Guinea.
#
# as
#  baby office that the of my like exclusive sight shorthand
#  Perhaps,' into the
#  of forward,
#  so edge Latin, fond - last on and the hands into nine grateful.

# %%
import annoy

# %%
import numpy as np

# %%
from simpleneighbors import SimpleNeighbors

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_md')

# %%
tbj = open("the_bell_jar.txt").read()

# %%
doc = nlp(tbj)

# %%
nouns = [item.text for item in doc if item.tag_ == 'NN']

# %%
prnouns = [item.text for item in doc if item.tag_ == 'PRP']

# %%
verbs = [item.text for item in doc if item.tag_ == 'VBD']

# %%
interjection = [item.text for item in doc if item.tag_ == 'UH']

# %%
conjuction = [item.text for item in doc if item.tag_ == 'CC']

# %%
adjective = [item.text for item in doc if item.tag_ == 'JJ']

# %%
preposition = [item.text for item in doc if item.tag_ == 'IN']

# %%
a_words_vb = [item for item in verbs if item.lower().startswith('a')]
b_words_vb = [item for item in verbs if item.lower().startswith('b')]
o_words_vb = [item for item in verbs if item.lower().startswith('o')]
t_words_vb = [item for item in verbs if item.lower().startswith('t')]
m_words_vb = [item for item in verbs if item.lower().startswith('m')]
l_words_vb = [item for item in verbs if item.lower().startswith('l')]
e_words_vb = [item for item in verbs if item.lower().startswith('e')]
s_words_vb = [item for item in verbs if item.lower().startswith('s')]
p_words_vb = [item for item in verbs if item.lower().startswith('p')]
i_words_vb = [item for item in verbs if item.lower().startswith('i')]
f_words_vb = [item for item in verbs if item.lower().startswith('f')]
h_words_vb = [item for item in verbs if item.lower().startswith('h')]
n_words_vb = [item for item in verbs if item.lower().startswith('n')]
g_words_vb = [item for item in verbs if item.lower().startswith('g')]

# %%
a_words_nn = [item for item in nouns if item.lower().startswith('a')]
b_words_nn = [item for item in nouns if item.lower().startswith('b')]
o_words_nn = [item for item in nouns if item.lower().startswith('o')]
t_words_nn = [item for item in nouns if item.lower().startswith('t')]
m_words_nn = [item for item in nouns if item.lower().startswith('m')]
l_words_nn = [item for item in nouns if item.lower().startswith('l')]
e_words_nn = [item for item in nouns if item.lower().startswith('e')]
s_words_nn = [item for item in nouns if item.lower().startswith('s')]
p_words_nn = [item for item in nouns if item.lower().startswith('p')]
i_words_nn = [item for item in nouns if item.lower().startswith('i')]
f_words_nn = [item for item in nouns if item.lower().startswith('f')]
h_words_nn = [item for item in nouns if item.lower().startswith('h')]
n_words_nn = [item for item in nouns if item.lower().startswith('n')]
g_words_nn = [item for item in nouns if item.lower().startswith('g')]

# %%
o_words_pn = [item for item in prnouns if item.lower().startswith('o')]
t_words_pn = [item for item in prnouns if item.lower().startswith('t')]
m_words_pn = [item for item in prnouns if item.lower().startswith('m')]
e_words_pn = [item for item in prnouns if item.lower().startswith('e')]
s_words_pn = [item for item in prnouns if item.lower().startswith('s')]
i_words_pn = [item for item in prnouns if item.lower().startswith('i')]
h_words_pn = [item for item in prnouns if item.lower().startswith('h')]

# %%
a_words_in = [item for item in interjection if item.lower().startswith('a')]
o_words_in = [item for item in interjection if item.lower().startswith('o')]
m_words_in = [item for item in interjection if item.lower().startswith('m')]
l_words_in = [item for item in interjection if item.lower().startswith('l')]
s_words_in = [item for item in interjection if item.lower().startswith('s')]
p_words_in = [item for item in interjection if item.lower().startswith('p')]
h_words_in = [item for item in interjection if iBut tem.lower().startswith('h')]
n_words_in = [item for item in interjection if item.lower().startswith('n')]
g_words_in = [item for item in interjection if item.lower().startswith('g')]

# %%
a_words_cj = [item for item in conjuction if item.lower().startswith('a')]
b_words_cj = [item for item in conjuction if item.lower().startswith('b')]
o_words_cj = [item for item in conjuction if item.lower().startswith('o')]
e_words_cj = [item for item in conjuction if item.lower().startswith('e')]
s_words_cj = [item for item in conjuction if item.lower().startswith('s')]
n_words_cj = [item for item in conjuction if item.lower().startswith('n')]

# %%
a_words_ad = [item for item in adjective if item.lower().startswith('a')]
b_words_ad = [item for item in adjective if item.lower().startswith('b')]
o_words_ad = [item for item in adjective if item.lower().startswith('o')]
t_words_ad = [item for item in adjective if item.lower().startswith('t')]
m_words_ad = [item for item in adjective if item.lower().startswith('m')]
l_words_ad = [item for item in adjective if item.lower().startswith('l')]
e_words_ad = [item for item in adjective if item.lower().startswith('e')]
s_words_ad = [item for item in adjective if item.lower().startswith('s')]
p_words_ad = [item for item in adjective if item.lower().startswith('p')]
i_words_ad = [item for item in adjective if item.lower().startswith('i')]
f_words_ad = [item for item in adjective if item.lower().startswith('f')]
h_words_ad = [item for item in adjective if item.lower().startswith('h')]
n_words_ad = [item for item in adjective if item.lower().startswith('n')]
g_words_ad = [item for item in adjective if item.lower().startswith('g')]

# %%
a_words_pp = [item for item in preposition if item.lower().startswith('a')]
b_words_pp = [item for item in preposition if item.lower().startswith('b')]
o_words_pp = [item for item in preposition if item.lower().startswith('o')]
t_words_pp = [item for item in preposition if item.lower().startswith('t')]
m_words_pp = [item for item in preposition if item.lower().startswith('m')]
l_words_pp = [item for item in preposition if item.lower().startswith('l')]
e_words_pp = [item for item in preposition if item.lower().startswith('e')]
s_words_pp = [item for item in preposition if item.lower().startswith('s')]
p_words_pp = [item for item in preposition if item.lower().startswith('p')]
i_words_pp = [item for item in preposition if item.lower().startswith('i')]
f_words_pp = [item for item in preposition if item.lower().startswith('f')]
h_words_pp = [item for item in preposition if item.lower().startswith('h')]
n_words_pp = [item for item in preposition if item.lower().startswith('n')]
g_words_pp = [item for item in preposition if item.lower().startswith('g')]

# %%
rules = {
        "origin": "#a_words_pp#\n #b_words_nn# #o_words_ad# #t_words_vb# #t_words_ad# #o_words_nn# #m_words_vb# #l_words_nn# #e_words_vb# #s_words_cj# #s_words_vb#\n #p_words_ad# #i_words_nn# #t_words_vb#\n #o_words_pp# #f_words_nn#\n #s_words_vb# #e_words_cj# #l_words_vb# #f_words_ad# - #l_words_in# #o_words_vb# #a_words_cj# #t_words_vb# #h_words_ad# #i_words_nn# #n_words_ad# #g_words_nn#."
    , 
        "a_words_vb" : a_words_vb,
        "b_words_vb": b_words_vb,
        "o_words_vb": o_words_vb,
        "t_words_vb": t_words_vb,
        "m_words_vb": m_words_vb,
        "l_words_vb": l_words_vb,
        "e_words_vb": e_words_vb,
        "s_words_vb": s_words_vb,
        "p_words_vb": p_words_vb,
        "i_words_vb": i_words_vb,
        "f_words_vb": f_words_vb,
        "h_words_vb": h_words_vb,
        "n_words_vb": n_words_vb,
        "g_words_vb": g_words_vb,
        "a_words_nn": a_words_nn,
        "b_words_nn": b_words_nn,
        "o_words_nn": o_words_nn,
        "t_words_nn": t_words_nn,
        "m_words_nn": m_words_nn,
        "l_words_nn": l_words_nn,
        "e_words_nn": e_words_nn,
        "s_words_nn": s_words_nn,
        "p_words_nn": p_words_nn,
        "i_words_nn": i_words_nn,
        "f_words_nn": f_words_nn,
        "h_words_nn": h_words_nn,
        "n_words_nn": n_words_nn,
        "g_words_nn": g_words_nn,
        "o_words_pn": o_words_pn,
        "t_words_pn": t_words_pn,
        "m_words_pn": m_words_pn,
        "e_words_pn": e_words_pn,
        "s_words_pn": s_words_pn,
        "p_words_pn": p_words_pn,
        "i_words_pn": i_words_pn,
        "h_words_pn": h_words_pn,
        "n_words_pn": n_words_pn,
        "a_words_in": a_words_in,
        "o_words_in": o_words_in,
        "m_words_in": m_words_in,
        "l_words_in": l_words_in,
        "s_words_in": s_words_in,
        "p_words_in": p_words_in,
        "h_words_in": h_words_in,
        "n_words_in": n_words_in, 
        "g_words_in": g_words_in,
        "a_words_cj": a_words_cj,
        "b_words_cj": b_words_cj,
        "o_words_cj": o_words_cj,
        "e_words_cj": e_words_cj,
        "s_words_cj": s_words_cj,
        "n_words_cj": n_words_cj,
        "a_words_ad": a_words_ad,
        "b_words_ad": b_words_ad,
        "o_words_ad": o_words_ad,
        "t_words_ad": t_words_ad,
        "m_words_ad": m_words_ad,
        "l_words_ad": l_words_ad,
        "e_words_ad": e_words_ad,
        "s_words_ad": s_words_ad,
        "p_words_ad": p_words_ad,
        "i_words_ad": i_words_ad,
        "f_words_ad": f_words_ad,
        "h_words_ad": h_words_ad,
        "n_words_ad": n_words_ad,
        "g_words_ad": g_words_ad,
        "a_words_pp": a_words_pp,
        "b_words_pp": b_words_pp,
        "o_words_pp": o_words_pp,
        "t_words_pp": t_words_pp,
        "m_words_pp": m_words_pp,
        "l_words_pp": l_words_pp,
        "e_words_pp": e_words_pp,
        "s_words_pp": s_words_pp,
        "p_words_pp": p_words_pp,
        "i_words_pp": i_words_pp,
        "f_words_pp": f_words_pp,
        "h_words_pp": h_words_pp,
        "n_words_pp": n_words_pp,
        "g_words_pp": g_words_pp,
       
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
print(grammar.flatten("#origin#"))
# Out:
# as
#  bag own the tasteless orchestra mouth, lichen every so she
#  pale idea the
#  of face
#  shock Either like first - like of and terry-towel haired incense nasty glass.

# %%
words_st = open("spinaltap.txt").read().split()

# %%
a_words_st = [item for item in words_st if item.lower().startswith('a')]
b_words_st = [item for item in words_st if item.lower().startswith('b')]
o_words_st = [item for item in words_st if item.lower().startswith('o')]
t_words_st = [item for item in words_st if item.lower().startswith('t')]
m_words_st = [item for item in words_st if item.lower().startswith('m')]
l_words_st = [item for item in words_st if item.lower().startswith('l')]
e_words_st = [item for item in words_st if item.lower().startswith('e')]
s_words_st = [item for item in words_st if item.lower().startswith('s')]
p_words_st = [item for item in words_st if item.lower().startswith('p')]
i_words_st = [item for item in words_st if item.lower().startswith('i')]
f_words_st = [item for item in words_st if item.lower().startswith('f')]
h_words_st = [item for item in words_st if item.lower().startswith('h')]
n_words_st = [item for item in words_st if item.lower().startswith('n')]
g_words_st = [item for item in words_st if item.lower().startswith('g')]

# %%
rules = {
        "origin": "#a_words_st#\n #b_words_st# #o_words_st# #t_words_st# #t_words_st# #o_words_st# #m_words_st# #l_words_st# #e_words_st# #s_words_st# #s_words_st#\n #p_words_st# #i_words_st# #t_words_st#\n #o_words_st# #f_words_st#\n #s_words_st# #e_words_st# #l_words_st# #f_words_st# - #l_words_st# #o_words_st# #a_words_st# #t_words_st# #h_words_st# #i_words_st# #n_words_st# #g_words_st#."
    ,
        "a_words_st": a_words_st, 
        "b_words_st": b_words_st,
        "o_words_st": o_words_st,
        "t_words_st": t_words_st,
        "m_words_st": m_words_st,
        "l_words_st": l_words_st,
        "e_words_st": e_words_st,
        "s_words_st": s_words_st,
        "p_words_st": p_words_st, 
        "i_words_st": i_words_st,
        "f_words_st": f_words_st,
        "h_words_st": h_words_st,
        "n_words_st": n_words_st,
        "g_words_st": g_words_st
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
print(grammar.flatten("#origin#"+"\n\n"+"#origin#"+"\n\n"+"#origin#"+"\n\n"+"#origin#"+"\n\n"+"#origin#"+"\n\n"+"#origin#"+"\n\n"))
# Out:
# a
#  band Oh, the then occur, me, literally exactly sort Saucy
#  played in the
#  on Flower
#  sort exhibit little for - Listen over and this hours I Nigel: guys.
#
# and
#  booked of the too, of more left... Extra: shuould someone
#  People! it to
#  on Farm"
#  saturate experimenting? leather. fucked - like; of again. the hundred is Nigel: golf?.
#
# any
#  brutally one tied that on me look...I...I...this exit. stupid stain,
#  point If trousers
#  of fourteen
#  seen experimenting literally for, - Lieutenant Other a to home....all Is Nigel: got.
#
# a
#  bird, old tell the on me, live even. Series' Shall
#  piece it's the
#  out for
#  Spinal else live from - like... of around that's him it Nigel: group.
#
# aren't
#  been of Tap, the of my like exactly stores sexist?
#  Personnel I tour,
#  once, for
#  supposed exiting looks finger? - let's or and that have It's Nigel: good.
#
# Album",
#  black?", of the that of, Mick: looks Eastern size. sounds,
#  point? I That's
# ...

# %%
song1 = open("song1.txt").read().split()
song2 = open("song2.txt").read().split()
song3 = open("song3.txt").read().split()
song4 = open("song4.txt").read().split()
song5 = open("song5.txt").read().split()
song6 = open("song6.txt").read().split()

# %%
a_words_1 = [item for item in song1 if item.lower().startswith('a')]
b_words_1 = [item for item in song1 if item.lower().startswith('b')]
o_words_1 = [item for item in song1 if item.lower().startswith('o')]
t_words_1 = [item for item in song1 if item.lower().startswith('t')]
m_words_1 = [item for item in song1 if item.lower().startswith('m')]
l_words_1 = [item for item in song1 if item.lower().startswith('l')]
e_words_1 = [item for item in song1 if item.lower().startswith('e')]
s_words_1 = [item for item in song1 if item.lower().startswith('s')]
p_words_1 = [item for item in song1 if item.lower().startswith('p')]
i_words_1 = [item for item in song1 if item.lower().startswith('i')]
f_words_1 = [item for item in song1 if item.lower().startswith('f')]
h_words_1 = [item for item in song1 if item.lower().startswith('h')]
n_words_1 = [item for item in song1 if item.lower().startswith('n')]
g_words_1 = [item for item in song1 if item.lower().startswith('g')]

# %%
rules = {
        "origin": "#a_words_1#\n #b_words_1# #o_words_1# #t_words_1# #t_words_1# #o_words_1# #m_words_1# #l_words_1# #e_words_1# #s_words_1# #s_words_1#\n #p_words_1# #i_words_1# #t_words_1#\n #o_words_1# #f_words_1#\n #s_words_1# #e_words_1# #l_words_1# #f_words_1# - #l_words_1# #o_words_1# #a_words_1# #t_words_1# #h_words_1# #i_words_1# #n_words_1# #g_words_1#."
    ,
        "a_words_1": a_words_1, 
        "b_words_1": b_words_1,
        "o_words_1": o_words_1,
        "t_words_1": t_words_1,
        "m_words_1": m_words_1,
        "l_words_1": l_words_1,
        "e_words_1": e_words_1,
        "s_words_1": s_words_1,
        "p_words_1": p_words_1, 
        "i_words_1": i_words_1,
        "f_words_1": f_words_1,
        "h_words_1": h_words_1,
        "n_words_1": n_words_1,
        "g_words_1": g_words_1
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
print(grammar.flatten("#origin#"+"\n\n"))
# Out:
# And
#  boy Oh, to taxes Oh, me let Everybody see Simply
#  Panic increase They
#  on Fore
#  Spend Everybody life finance - livin' on And They Hang increasing no God.

# %%
a_words_2 = [item for item in song2 if item.lower().startswith('a')]
b_words_2 = [item for item in song2 if item.lower().startswith('b')]
o_words_2 = [item for item in song2 if item.lower().startswith('o')]
t_words_2 = [item for item in song2 if item.lower().startswith('t')]
m_words_2 = [item for item in song2 if item.lower().startswith('m')]
l_words_2 = [item for item in song2 if item.lower().startswith('l')]
e_words_2 = [item for item in song2 if item.lower().startswith('e')]
s_words_2 = [item for item in song2 if item.lower().startswith('s')]
p_words_2 = [item for item in song2 if item.lower().startswith('p')]
i_words_2 = [item for item in song2 if item.lower().startswith('i')]
f_words_2 = [item for item in song2 if item.lower().startswith('f')]
h_words_2 = [item for item in song2 if item.lower().startswith('h')]
n_words_2 = [item for item in song2 if item.lower().startswith('n')]
g_words_2 = [item for item in song2 if item.lower().startswith('g')]

# %%
rules = {
        "origin": "#a_words_2#\n #b_words_2# #o_words_2# #t_words_2# #t_words_2# #o_words_2# #m_words_2# #l_words_2# #e_words_2# #s_words_2# #s_words_2#\n #p_words_2# #i_words_2# #t_words_2#\n #o_words_2# #f_words_2#\n #s_words_2# #e_words_2# #l_words_2# #f_words_2# - #l_words_2# #o_words_2# #a_words_2# #t_words_2# #h_words_2# #i_words_2# #n_words_2# #g_words_2#."
    ,
        "a_words_2": a_words_2, 
        "b_words_2": b_words_2,
        "o_words_2": o_words_2,
        "t_words_2": t_words_2,
        "m_words_2": m_words_2,
        "l_words_2": l_words_2,
        "e_words_2": e_words_2,
        "s_words_2": s_words_2,
        "p_words_2": p_words_2, 
        "i_words_2": i_words_2,
        "f_words_2": f_words_2,
        "h_words_2": h_words_2,
        "n_words_2": n_words_2,
        "g_words_2": g_words_2
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
print(grammar.flatten("#origin#"+"\n\n"))
# Out:
# and
#  bitter, out the the on my Like ex say stomach
#  place I'm that
#  of first
#  soap ex lips final - Like out And There'll hurt, is no goes,.

# %%
a_words_3 = [item for item in song3 if item.lower().startswith('a')]
b_words_3 = [item for item in song3 if item.lower().startswith('b')]
o_words_3 = [item for item in song3 if item.lower().startswith('o')]
t_words_3 = [item for item in song3 if item.lower().startswith('t')]
m_words_3 = [item for item in song3 if item.lower().startswith('m')]
l_words_3 = [item for item in song3 if item.lower().startswith('l')]
e_words_3 = [item for item in song3 if item.lower().startswith('e')]
s_words_3 = [item for item in song3 if item.lower().startswith('s')]
p_words_3 = [item for item in song3 if item.lower().startswith('p')]
i_words_3 = [item for item in song3 if item.lower().startswith('i')]
f_words_3 = [item for item in song3 if item.lower().startswith('f')]
h_words_3 = [item for item in song3 if item.lower().startswith('h')]
n_words_3 = [item for item in song3 if item.lower().startswith('n')]
g_words_3 = [item for item in song3 if item.lower().startswith('g')]

# %%
rules = {
        "origin": "#a_words_3#\n #b_words_3# #o_words_3# #t_words_3# #t_words_3# #o_words_3# #m_words_3# #l_words_3# #e_words_3# #s_words_3# #s_words_3#\n #p_words_3# #i_words_3# #t_words_3#\n #o_words_3# #f_words_3#\n #s_words_3# #e_words_3# #l_words_3# #f_words_3# - #l_words_3# #o_words_3# #a_words_3# #t_words_3# #h_words_3# #i_words_3# #n_words_3# #g_words_3#."
    ,
        "a_words_3": a_words_3, 
        "b_words_3": b_words_3,
        "o_words_3": o_words_3,
        "t_words_3": t_words_3,
        "m_words_3": m_words_3,
        "l_words_3": l_words_3,
        "e_words_3": e_words_3,
        "s_words_3": s_words_3,
        "p_words_3": p_words_3, 
        "i_words_3": i_words_3,
        "f_words_3": f_words_3,
        "h_words_3": h_words_3,
        "n_words_3": n_words_3,
        "g_words_3": g_words_3
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
print(grammar.flatten("#origin#"+"\n\n"))
# Out:
# answer
#  began Or to that oh my love eyes said so
#  plain In thing
#  only fling
#  suspect ever light for - light out another to had I never girl,.

# %%
a_words_4 = [item for item in song4 if item.lower().startswith('a')]
b_words_4 = [item for item in song4 if item.lower().startswith('b')]
o_words_4 = [item for item in song4 if item.lower().startswith('o')]
t_words_4 = [item for item in song4 if item.lower().startswith('t')]
m_words_4 = [item for item in song4 if item.lower().startswith('m')]
l_words_4 = [item for item in song4 if item.lower().startswith('l')]
e_words_4 = [item for item in song4 if item.lower().startswith('e')]
s_words_4 = [item for item in song4 if item.lower().startswith('s')]
p_words_4 = [item for item in song4 if item.lower().startswith('p')]
i_words_4 = [item for item in song4 if item.lower().startswith('i')]
f_words_4 = [item for item in song4 if item.lower().startswith('f')]
h_words_4 = [item for item in song4 if item.lower().startswith('h')]
n_words_4 = [item for item in song4 if item.lower().startswith('n')]
g_words_4 = [item for item in song4 if item.lower().startswith('g')]

# %%
rules = {
        "origin": "#a_words_4#\n #b_words_4# #o_words_4# #t_words_4# #t_words_4# #o_words_4# #m_words_4# #l_words_4# #e_words_4# #s_words_4# #s_words_4#\n #p_words_4# #i_words_4# #t_words_4#\n #o_words_4# #f_words_4#\n #s_words_4# #e_words_4# #l_words_4# #f_words_4# - #l_words_4# #o_words_4# #a_words_4# #t_words_4# #h_words_4# #i_words_4# #n_words_4# #g_words_4#."
    ,
        "a_words_4": a_words_4, 
        "b_words_4": b_words_4,
        "o_words_4": o_words_4,
        "t_words_4": t_words_4,
        "m_words_4": m_words_4,
        "l_words_4": l_words_4,
        "e_words_4": e_words_4,
        "s_words_4": s_words_4,
        "p_words_4": p_words_4, 
        "i_words_4": i_words_4,
        "f_words_4": f_words_4,
        "h_words_4": h_words_4,
        "n_words_4": n_words_4,
        "g_words_4": g_words_4
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
print(grammar.flatten("#origin#"+"\n\n"))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-301-039e4ff89132> in <module>
#      19 grammar = tracery.Grammar(rules)
#      20 grammar.add_modifiers(base_english)
# ---> 21 print(grammar.flatten("#origin#"+"\n\n"))
#
# /anaconda3/lib/python3.7/site-packages/tracery/__init__.py in flatten(self, rule, allow_escape_chars)
#     242
#     243     def flatten(self, rule, allow_escape_chars=False):
# --> 244         root = self.expand(rule, allow_escape_chars)
#     245         return root.finished_text
#     246
#
# /anaconda3/lib/python3.7/site-packages/tracery/__init__.py in expand(self, rule, allow_escape_chars)
#     235     def expand(self, rule, allow_escape_chars=False):
#     236         root = self.create_root(rule)
# --> 237         root.expand()
#     238         if not allow_escape_chars:
#     239             root.clear_escape_chars()
#
# ...
